# %% [markdown]
# <a href="https://colab.research.google.com/github/sisterme3/SVD-NMF-topic-extraction/blob/master/Small_example_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.linalg import svd as scipy_svd
from sklearn.decomposition import TruncatedSVD, NMF
from sklearn.preprocessing import normalize, StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer


example= [
    'Machine learning is super fun',
    'Python is super, super cool',
    'Statistics is cool, too',
    'Data science is fun',
    'Python is great for machine learning',
    'I like football',
    'Football is great to watch',
    'Python is a great way to learn', 
    'Data Science is amazing',
    'Football is an interesting sport']


f = open("test.txt", newline='', encoding="iso-8859-1")
x = f.readlines()
f.close()


#This method prints out the top words that the models extract from the text dataset
n_top_words = 5

def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += " ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)
    print()

    
    
# Term-document matrix object
tfidf = TfidfVectorizer(stop_words = 'english')

#These are the SVD and N models
svd = TruncatedSVD(n_components =700)
N = NMF()

#Creates a term-document matrix from the example
bob= tfidf.fit_transform(x)

#Performs the factorization for each thing
X_lsa = svd.fit_transform(bob)
okay = N.fit_transform(bob)



#Gets the feature names(words) from the example minus the stop words(and, the, a, etc.)
vocab = tfidf.get_feature_names()



"This prints out the factorization for each model"
pd.DataFrame(svd.components_, index = ['concept1', 'concept2'], columns = vocab)

pd.DataFrame(N.components_, index=['concept1', 'concept2'], columns =vocab)





"These are different statistics for each model"

print('total variance explained:', svd.explained_variance_)

print('Singular Values:', svd.singular_values_)

print('Singular Values:', P.explained_variance_)

print('Frobenius norm:', N.reconstruction_err_ )

print('Number of iterations', N.n_iter_)



"This is the cool correlation matrix with the values"

ds=N.transform(bob)
hu=svd.transform(bob)

joe=pd.DataFrame(hu, index = example, columns = ['science', 'football'])
joe.style.background_gradient(cmap='Reds')


ui=pd.DataFrame(ds, index = example, columns = ['science', 'football'])
ui.style.background_gradient(cmap='Reds')

"This prints out the top words"
print('Nonnegative Factorization')
print_top_words(N, vocab, n_top_words)

print('Singular Value Decomposition')
print_top_words(svd, vocab, n_top_words)


print('feature words')
vocab
# Out:
# Singular Value Decomposition
# Topic #0: rsa key public des pgp
# Topic #1: rsa pgp library security routines
# Topic #2: pgp use compatible pem 13
# Topic #3: des pem uses mail encrypts
# Topic #4: pem mail enhanced privacy mime
# Topic #5: edu indiana mvanheyn ucs cs
# Topic #6: fingerprint md5 like message encrypted
# Topic #7: keys authenticating des distributing does
# Topic #8: security alt answers comp mail
# Topic #9: permanent citizens residents ftp canada
# Topic #10: mail cryptographic privacy mime program
# Topic #11: use mime author included secure
# Topic #12: export cryptographic code public license
# Topic #13: public use used encryption rpem
# Topic #14: users described guide included cryptographic
# Topic #15: faq considered users legal advice
# Topic #16: read file message decrypt crypt
# Topic #17: users mailer described mime message
# Topic #18: run fingerprint machine plaintext secure
# Topic #19: secure mailer cryptographically plaintext work
# ...
